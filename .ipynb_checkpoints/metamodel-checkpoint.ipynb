# %%
import pandas as pd
from scipy import stats
import json
import copy


pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
class JSONFlattener:
    def __init__(self, depth = 1, prefix = ''):
        self.prefix = prefix
        self.depth = depth
    
    def fit(x):
        self.possible_columns = list()
        for i in x:
            self.possible_columns.extend(list(i.keys()))
        self.possible_columns = sorted(list(set(self.possible_columns)))
        self.col_names = dict()
        for i in self.possible_columns:
            if self.prefix:
                self.col_names[i] = '{0}_{1}'.format(prefix, i)
            else:
                self.col_names[i] = i
        
    def transform(x):
        data_dicts = list()
        for i in x:
            temp_dict = dict()
            for j in self.possible_columns:
                temp_dict[self.col_names[j]] = i.get(j)
        return pd.DataFrame(data_dicts)

# %%
with open(r'C:\Users\TristanDelforge\Documents\data_files/1.json', 'r') as f:
    past_results = json.load(f)
past_results.keys()
# Out:
# dict_keys(['models', 'datasets', 'results'])

# %%
# with open('/home/td/Documents/datasets/auto_ml/1.json', 'r') as f:
#     past_results = json.load(f)
# past_results.keys()

# %%
model_df = pd.DataFrame(past_results['models'])
model_df.head(20)
# Out:
#                             model_id     model_type                                       model_params
# 0   0ab0614cca25431987f9f09042309894  LGBMRegressor  {'objective': 'fair', 'boosting_type': 'dart',...
# 1   ce64f93c2e854c37907f311c608207b7  LGBMRegressor  {'objective': 'huber', 'boosting_type': 'dart'...
# 2   9fa10367d9aa40d7b8b5fbc922b627d9     ElasticNet  {'alpha': 1.4543046401284723, 'l1_ratio': 0.21...
# 3   22055b8179f8401bbf4b05d6dbc15f0f  LGBMRegressor  {'objective': 'fair', 'boosting_type': 'goss',...
# 4   65b11677bb714119896c4bb9c5f64465  LGBMRegressor  {'objective': 'tweedie', 'boosting_type': 'gbd...
# 5   b70ec5baf1a64c1e9db020b0cfafc61d  LGBMRegressor  {'objective': 'quantile', 'boosting_type': 'da...
# 6   1e49256a08e7486cb55c0e37d52e0e95     ElasticNet  {'alpha': 0.17591996002623844, 'l1_ratio': 0.6...
# 7   55520514a8a545e7a618082f25cbc496  LGBMRegressor  {'objective': 'l1', 'boosting_type': 'goss', '...
# 8   a48986a3e4604bef8b46a3ffd63cebbc  LGBMRegressor  {'objective': 'quantile', 'boosting_type': 'go...
# 9   fdefecda941f4de0a4be214871fe8073     ElasticNet  {'alpha': 0.6068155327898019, 'l1_ratio': 0.25...
# 10  6cc324fe58834ad785eef6f8df0fd05b     ElasticNet  {'alpha': 1.7182984423424132, 'l1_ratio': 0.03...
# 11  e1ae4599df1549ce8b6924e3472bbac4  LGBMRegressor  {'objective': 'tweedie', 'boosting_type': 'gos...
# 12  c1c16830d199484ebd22b185e2125b2d     ElasticNet  {'alpha': 1.1198779540276689, 'l1_ratio': 0.23...
# 13  e1d7a3caeaf44bd39e0b7b6c92c4fb00  LGBMRegressor  {'objective': 'l1', 'boosting_type': 'gbdt', '...
# 14  2d0ee54fbe8a485ba428f6c861ef9d74  LGBMRegressor  {'objective': 'poisson', 'boosting_type': 'gos...
# 15  d6bea759789040e39aea77687de168eb  LGBMRegressor  {'objective': 'l2', 'boosting_type': 'gbdt', '...
# 16  ed83d20c4f98480ab7ecf47a786bfab3     ElasticNet  {'alpha': 1.974745577980099, 'l1_ratio': 0.724...
# 17  92868cc0434547a5b51f251959646b28     ElasticNet  {'alpha': 0.7116349600830818, 'l1_ratio': 0.61...
# 18  1613ce0ebc964e7fbc6b512819902d68     ElasticNet  {'alpha': 0.9482291836941528, 'l1_ratio': 0.97...
# 19  724c3bb268c94d51a3c5505fd508b222     ElasticNet  {'alpha': 1.601244212297903, 'l1_ratio': 0.725...

# %%
transformation_dicts = list()
general_state_dicts = list()

for i in past_results['datasets']:
    for j in i:
        new_transformation_dict = {'dataset_id': j['dataset_id'],
                                  'transformation_type': j['transformation_type']}
        new_transformation_dict.update(transformation_parameters)
        for n, k in enumerate(j['input_column_descriptions']):
            d_copy = copy.deepcopy(k)
            
        transformation_dicts.append(transformation_dicts)
# Out:
# 1
# 6
# 6
# 6
# 6
# 6
# 6

# %%
past_results['datasets'][1][0]
# Out:
# {'input_column_descriptions': [{'target': 0,
#    'original_column': 1,
#    'type': 'numeric',
#    'nan_count': 0,
#    'mean': 4.708145814581458,
#    'min': 1.0,
#    'max': 6.0,
#    'median': 5.0,
#    'skew': -1.0661712514181392,
#    'perc_unique': 0.000375037503750375,
#    'perc_of_values_mode': 0.36663666366636666,
#    'mode': 5.0,
#    'kurtosis': 0.41570635786714627,
#    'target_slope': 5508.931251509708,
#    'target_intercept': 53237.67576312534,
#    'target_r_value': 0.10664399554246792,
#    'target_p_value': 5.015997716008367e-35,
#    'target_std_err': 444.8689718889991}],
#  'general_description': {'rows': 13332,
#   'columns': 164,
#   'feature_columns_size': 0},
#  'dataset_id': '0c05a45e117447528fcbc9aee022cc10',
#  'datapath': 'C:\\Users\\TristanDelforge\\Documents\\data_files\\stackoverflow_survey_clean.csv',
#  'transformation_type': 'identity',
#  'transformation_parameters': {}}

# %%
past_results['datasets'][1][1]
# Out:
# {'input_column_descriptions': [{'target': 0,
#    'original_column': 1,
#    'type': 'numeric',
#    'nan_count': 0,
#    'mean': 1.5047254725472547,
#    'min': 0.0,
#    'max': 11.0,
#    'median': 1.0,
#    'skew': 3.453341499437557,
#    'perc_unique': 0.0008250825082508251,
#    'perc_of_values_mode': 0.7378487848784878,
#    'mode': 1.0,
#    'kurtosis': 14.028081642798242,
#    'target_slope': -3170.2833857878895,
#    'target_intercept': 83944.93354352616,
#    'target_r_value': -0.06905389770752059,
#    'target_p_value': 1.4393460912033422e-15,
#    'target_std_err': 396.69514243387556},
#   {'target': 0,
#    'original_column': 1,
#    'type': 'numeric',
#    'nan_count': 0,
#    'mean': 3.8208070807080707,
#    'min': 1.0,
#    'max': 6.0,
#    'median': 4.0,
#    'skew': 0.014228205754723281,
#    'perc_unique': 0.000375037503750375,
#    'perc_of_values_mode': 0.31743174317431744,
#    'mode': 6.0,
#    'kurtosis': -1.3965056857754405,
#    'target_slope': 824.3702606575713,
#    'target_intercept': 76024.76764869217,
#    'target_r_value': 0.021377596484219847,
#    'target_p_value': 0.013571879269597052,
#    'target_std_err': 333.9251324143267},
#   {'target': 0,
#    'original_column': 1,
#    'type': 'numeric',
#    'nan_count': 0,
#    'mean': 3.743699369936994,
#    'min': 0.0,
#    'max': 7.0,
#    'median': 4.0,
#    'skew': -0.21552006465915588,
#    'perc_unique': 0.000525052505250525,
#    'perc_of_values_mode': 0.16344134413441344,
#    'mode': 6.0,
#    'kurtosis': -1.2694883704447277,
#    'target_slope': 799.9184146015119,
#    'target_intercept': 76179.87331299309,
#    'target_r_value': 0.02825337343194746,
#    'target_p_value': 0.0011039490636023028,
#    'target_std_err': 245.12460257256868}],
#  'general_description': {'rows': 13332,
#   'columns': 165,
#   'feature_columns_size': 1},
#  'dataset_id': '0c05a45e117447528fcbc9aee022cc10',
#  'datapath': 'C:\\Users\\TristanDelforge\\Documents\\data_files\\stackoverflow_survey_clean.csv',
#  'transformation_type': 'product',
#  'transformation_parameters': {}}
