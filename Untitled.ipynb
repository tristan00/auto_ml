# %%
import pandas as pd
from scipy import stats
import json

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
with open('/home/td/Documents/datasets/auto_ml/1.json', 'r') as f:
    past_results = json.load(f)
past_results.keys()
# Out:
# dict_keys(['models', 'datasets', 'results'])

# %%
model_df = pd.DataFrame(past_results['models'])
model_df.head()
# Out:
#                            model_id     model_type                                       model_params
# 0  ee545d137ef246e8bb7225e4a61584d9  LGBMRegressor  {'objective': 'poisson', 'boosting_type': 'dar...
# 1  263a6ee5ee094373a7ae0ce2840f9c59     ElasticNet  {'alpha': 0.979249068975623, 'l1_ratio': 0.932...
# 2  7c9d8e3f75f74c40adec6834ddee4f2c  LGBMRegressor  {'objective': 'tweedie', 'boosting_type': 'gos...
# 3  ff8dff8eb2c44b53ab80668f61874b4b  LGBMRegressor  {'objective': 'huber', 'boosting_type': 'goss'...
# 4  7740f8fbd65d434bbbd8aacf98ad5100  LGBMRegressor  {'objective': 'l2', 'boosting_type': 'dart', '...

# %%
past_results['datasets'][:4]
# Out:
# [[{'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 57.403640256959314,
#      'min': 20.0,
#      'max': 190.0,
#      'median': 50.0,
#      'skew': 1.4102364012197977,
#      'perc_unique': 0.014989293361884369,
#      'perc_of_values_mode': 0.35974304068522484,
#      'mode': 20.0,
#      'kurtosis': 1.5806307806274136,
#      'target_slope': -209.28573543648187,
#      'target_intercept': 194283.71810002887,
#      'target_r_value': -0.1129103792613073,
#      'target_p_value': 0.0005459399735966862,
#      'target_std_err': 60.32698926148947}],
#    'general_description': {'rows': 934,
#     'columns': 84,
#     'feature_columns_size': 0},
#    'dataset_id': 'ac9c433864fe4d4f86437152726b9719',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'quantile_scaler',
#    'transformation_parameters': {}}],
#  [{'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 6.586723768736617,
#      'min': 2.0,
#      'max': 14.0,
#      'median': 6.0,
#      'skew': 0.6175598118023485,
#      'perc_unique': 0.011777301927194861,
#      'perc_of_values_mode': 0.2623126338329764,
#      'mode': 6.0,
#      'kurtosis': 0.840940027620948,
#      'target_slope': 25832.34683740624,
#      'target_intercept': 12119.422115928057,
#      'target_r_value': 0.5419792916106095,
#      'target_p_value': 1.9910649889036952e-72,
#      'target_std_err': 1312.0640665255178}],
#    'general_description': {'rows': 934,
#     'columns': 84,
#     'feature_columns_size': 0},
#    'dataset_id': 'f8f836f38b0d44ad928e700d19eebea7',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'identity',
#    'transformation_parameters': {}}],
#  [{'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 1971.4967880085653,
#      'min': 1872.0,
#      'max': 2010.0,
#      'median': 1974.5,
#      'skew': -0.6562348313020986,
#      'perc_unique': 0.11563169164882227,
#      'perc_of_values_mode': 0.05032119914346895,
#      'mode': 2005.0,
#      'kurtosis': -0.37384078203788107,
#      'target_slope': 1325.6812526850747,
#      'target_intercept': -2431306.376559676,
#      'target_r_value': 0.5131984051783707,
#      'target_p_value': 6.966995251817235e-64,
#      'target_std_err': 72.62226569406046},
#     {'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 1974.252676659529,
#      'min': 1899.0,
#      'max': 2010.0,
#      'median': 1978.0,
#      'skew': -0.9238021214428892,
#      'perc_unique': 0.10278372591006424,
#      'perc_of_values_mode': 0.055674518201284794,
#      'mode': 1899.0,
#      'kurtosis': 0.0991245085967205,
#      'target_slope': 1323.5346075041834,
#      'target_intercept': -2430721.7864845335,
#      'target_r_value': 0.5082238739123109,
#      'target_p_value': 1.7315342073400314e-62,
#      'target_std_err': 73.46642544084692}],
#    'general_description': {'rows': 934,
#     'columns': 84,
#     'feature_columns_size': 0},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'product',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 6.139186295503212,
#      'min': 1.0,
#      'max': 10.0,
#      'median': 6.0,
#      'skew': 0.189343029357604,
#      'perc_unique': 0.009635974304068522,
#      'perc_of_values_mode': 0.2633832976445396,
#      'mode': 6.0,
#      'kurtosis': 0.07945297421141406,
#      'target_slope': 44837.36991529673,
#      'target_intercept': -92995.01187827779,
#      'target_r_value': 0.7773855116778086,
#      'target_p_value': 7.661502988289413e-190,
#      'target_std_err': 1188.4016934705587},
#     {'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 48.41648822269807,
#      'min': 0.0,
#      'max': 547.0,
#      'median': 28.0,
#      'skew': 2.541994210755718,
#      'perc_unique': 0.1809421841541756,
#      'perc_of_values_mode': 0.4421841541755889,
#      'mode': 0.0,
#      'kurtosis': 9.464905803029934,
#      'target_slope': 319.2687984558832,
#      'target_intercept': 166812.08101180568,
#      'target_r_value': 0.2832473419134387,
#      'target_p_value': 1.0826962176834548e-18,
#      'target_std_err': 35.40972234943659}],
#    'general_description': {'rows': 934,
#     'columns': 85,
#     'feature_columns_size': 1},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'difference',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 0.4400428265524625,
#      'min': 0.0,
#      'max': 3.0,
#      'median': 0.0,
#      'skew': 0.5951134739970712,
#      'perc_unique': 0.0032119914346895075,
#      'perc_of_values_mode': 0.5738758029978587,
#      'mode': 0.0,
#      'kurtosis': -0.6714535845682628,
#      'target_slope': 28199.278886792163,
#      'target_intercept': 169861.06464403472,
#      'target_r_value': 0.18778316411154725,
#      'target_p_value': 7.348867608781071e-09,
#      'target_std_err': 4831.455348776795},
#     {'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 5.534261241970022,
#      'min': 0.0,
#      'max': 572.0,
#      'median': 0.0,
#      'skew': 9.622607095820726,
#      'perc_unique': 0.017130620985010708,
#      'perc_of_values_mode': 0.9817987152034261,
#      'mode': 0.0,
#      'kurtosis': 95.6353279382142,
#      'target_slope': -18.255065485648387,
#      'target_intercept': 182370.98333350677,
#      'target_r_value': -0.0109468819712937,
#      'target_p_value': 0.7382933994458338,
#      'target_std_err': 54.62091615063458},
#     {'target': 0,
#      'original_column': 0,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': -42.27730192719486,
#      'min': -541.0,
#      'max': 10.0,
#      'median': -22.0,
#      'skew': -2.569471961082673,
#      'perc_unique': 0.20770877944325483,
#      'perc_of_values_mode': 0.1734475374732334,
#      'mode': 5.0,
#      'kurtosis': 9.646185943574606,
#      'target_slope': -305.4805668256009,
#      'target_intercept': 169355.06087554336,
#      'target_r_value': -0.2695308435885969,
#      'target_p_value': 5.2119041110286685e-17,
#      'target_std_err': 35.751126501069926},
#     {'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 350.9892933618844,
#      'min': 0.0,
#      'max': 1872.0,
#      'median': 0.0,
#      'skew': 0.7640305136612782,
#      'perc_unique': 0.31156316916488225,
#      'perc_of_values_mode': 0.5674518201284796,
#      'mode': 0.0,
#      'kurtosis': -0.7605532496333347,
#      'target_slope': 51.67023084494097,
#      'target_intercept': 164134.25722000864,
#      'target_r_value': 0.287073351805129,
#      'target_p_value': 3.532868756319752e-19,
#      'target_std_err': 5.647596222111954},
#     {'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 1178.2173447537473,
#      'min': 334.0,
#      'max': 4692.0,
#      'median': 1095.5,
#      'skew': 1.5567755350977677,
#      'perc_unique': 0.6177730192719486,
#      'perc_of_values_mode': 0.013918629550321198,
#      'mode': 864.0,
#      'kurtosis': 6.857692978608437,
#      'target_slope': 115.94833961201178,
#      'target_intercept': 45657.61020584966,
#      'target_r_value': 0.5992331076326987,
#      'target_p_value': 4.066076893297036e-92,
#      'target_std_err': 5.0741415945903485},
#     {'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 1971.4967880085653,
#      'min': 1872.0,
#      'max': 2010.0,
#      'median': 1974.5,
#      'skew': -0.6562348313020986,
#      'perc_unique': 0.11563169164882227,
#      'perc_of_values_mode': 0.05032119914346895,
#      'mode': 2005.0,
#      'kurtosis': -0.37384078203788107,
#      'target_slope': 1325.6812526850747,
#      'target_intercept': -2431306.376559676,
#      'target_r_value': 0.5131984051783707,
#      'target_p_value': 6.966995251817235e-64,
#      'target_std_err': 72.62226569406046},
#     {'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 22.298715203426124,
#      'min': 0.0,
#      'max': 552.0,
#      'median': 0.0,
#      'skew': 3.210972194379572,
#      'perc_unique': 0.09850107066381156,
#      'perc_of_values_mode': 0.8565310492505354,
#      'mode': 0.0,
#      'kurtosis': 11.710763108150621,
#      'target_slope': -138.5812797912183,
#      'target_intercept': 185360.13952271058,
#      'target_r_value': -0.10972601729626832,
#      'target_p_value': 0.0007821411963048803,
#      'target_std_err': 41.12034222981078}],
#    'general_description': {'rows': 934,
#     'columns': 86,
#     'feature_columns_size': 2,
#     'mean_nan_count': 0,
#     'mean_mean': 1946446.4518201286,
#     'mean_min': -42.27730192719486,
#     'mean_max': 3892935.1809421843,
#     'mean_median': 1946446.4518201286,
#     'mean_skew': nan,
#     'mean_perc_unique': 0.5,
#     'mean_perc_of_values_mode': 0.5,
#     'mean_mode': 3892935.1809421843,
#     'mean_kurtosis': -2.0,
#     'min_nan_count': 0,
#     'min_mean': 1777193.5,
#     'min_min': -541.0,
#     'min_max': 3554928.0,
#     'min_median': 1777193.5,
#     'min_skew': nan,
#     'min_perc_unique': 0.5,
#     'min_perc_of_values_mode': 0.5,
#     'min_mode': -541.0,
#     'min_kurtosis': -2.0,
#     'max_nan_count': 0,
#     'max_mean': 2020055.0,
#     'max_min': 10.0,
#     'max_max': 4040100.0,
#     'max_median': 2020055.0,
#     'max_skew': nan,
#     'max_perc_unique': 0.5,
#     'max_perc_of_values_mode': 0.5,
#     'max_mode': 4040100.0,
#     'max_kurtosis': -2.0,
#     'median_nan_count': 0,
#     'median_mean': 1952064.5,
#     'median_min': -22.0,
#     'median_max': 3904151.0,
#     'median_median': 1952064.5,
#     'median_skew': nan,
#     'median_perc_unique': 0.5,
#     'median_perc_of_values_mode': 0.5,
#     'median_mode': 3904151.0,
#     'median_kurtosis': -2.0,
#     'skew_nan_count': 0,
#     'skew_mean': -1.55284686325962,
#     'skew_min': -2.569471961082673,
#     'skew_max': -0.5362217654365666,
#     'skew_median': -1.55284686325962,
#     'skew_skew': nan,
#     'skew_perc_unique': 0.5,
#     'skew_perc_of_values_mode': 0.5,
#     'skew_mode': -0.5362217654365666,
#     'skew_kurtosis': -2.0,
#     'perc_unique_nan_count': 0,
#     'perc_unique_mean': 0.2580299785867238,
#     'perc_unique_min': 0.20770877944325483,
#     'perc_unique_max': 0.3083511777301927,
#     'perc_unique_median': 0.2580299785867238,
#     'perc_unique_skew': nan,
#     'perc_unique_perc_unique': 0.5,
#     'perc_unique_perc_of_values_mode': 0.5,
#     'perc_unique_mode': 0.20770877944325483,
#     'perc_unique_kurtosis': -2.0,
#     'perc_of_values_mode_nan_count': 0,
#     'perc_of_values_mode_mean': 0.11081370449678801,
#     'perc_of_values_mode_min': 0.048179871520342615,
#     'perc_of_values_mode_max': 0.1734475374732334,
#     'perc_of_values_mode_median': 0.11081370449678801,
#     'perc_of_values_mode_skew': nan,
#     'perc_of_values_mode_perc_unique': 0.5,
#     'perc_of_values_mode_perc_of_values_mode': 0.5,
#     'perc_of_values_mode_mode': 0.1734475374732334,
#     'perc_of_values_mode_kurtosis': -2.0,
#     'mode_nan_count': 0,
#     'mode_mean': 2010015.0,
#     'mode_min': 5.0,
#     'mode_max': 4020025.0,
#     'mode_median': 2010015.0,
#     'mode_skew': nan,
#     'mode_perc_unique': 0.5,
#     'mode_perc_of_values_mode': 0.5,
#     'mode_mode': 4020025.0,
#     'mode_kurtosis': -2.0,
#     'kurtosis_nan_count': 0,
#     'kurtosis_mean': 4.502697104528815,
#     'kurtosis_min': -0.6407917345169745,
#     'kurtosis_max': 9.646185943574606,
#     'kurtosis_median': 4.502697104528815,
#     'kurtosis_skew': nan,
#     'kurtosis_perc_unique': 0.5,
#     'kurtosis_perc_of_values_mode': 0.5,
#     'kurtosis_mode': 9.646185943574606,
#     'kurtosis_kurtosis': -1.9999999999999998,
#     'target_slope_nan_count': 0,
#     'target_slope_mean': -152.5482060362929,
#     'target_slope_min': -305.4805668256009,
#     'target_slope_max': 0.3841547530150552,
#     'target_slope_median': -152.5482060362929,
#     'target_slope_skew': nan,
#     'target_slope_perc_unique': 0.5,
#     'target_slope_perc_of_values_mode': 0.5,
#     'target_slope_mode': -305.4805668256009,
#     'target_slope_kurtosis': -2.0,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': -571932.2685154004,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 169355.06087554336,
#     'target_intercept_median': -571932.2685154004,
#     'target_intercept_skew': nan,
#     'target_intercept_perc_unique': 0.5,
#     'target_intercept_perc_of_values_mode': 0.5,
#     'target_intercept_mode': -1313219.597906344,
#     'target_intercept_kurtosis': -2.0,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': 0.13836453508243218,
#     'target_r_value_min': -0.2695308435885969,
#     'target_r_value_max': 0.5462599137534613,
#     'target_r_value_median': 0.13836453508243218,
#     'target_r_value_skew': nan,
#     'target_r_value_perc_unique': 0.5,
#     'target_r_value_perc_of_values_mode': 0.5,
#     'target_r_value_mode': -0.2695308435885969,
#     'target_r_value_kurtosis': -2.0,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 2.6059520555143342e-17,
#     'target_p_value_min': 9.044925393388627e-74,
#     'target_p_value_max': 5.2119041110286685e-17,
#     'target_p_value_median': 2.6059520555143342e-17,
#     'target_p_value_skew': nan,
#     'target_p_value_perc_unique': 0.5,
#     'target_p_value_perc_of_values_mode': 0.5,
#     'target_p_value_mode': 5.2119041110286685e-17,
#     'target_p_value_kurtosis': -2.0,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 17.885210727503804,
#     'target_std_err_min': 0.01929495393767906,
#     'target_std_err_max': 35.751126501069926,
#     'target_std_err_median': 17.885210727503804,
#     'target_std_err_skew': nan,
#     'target_std_err_perc_unique': 0.5,
#     'target_std_err_perc_of_values_mode': 0.5,
#     'target_std_err_mode': 35.751126501069926,
#     'target_std_err_kurtosis': -2.0},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'product',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 57.403640256959314,
#      'min': 20.0,
#      'max': 190.0,
#      'median': 50.0,
#      'skew': 1.4102364012197977,
#      'perc_unique': 0.014989293361884369,
#      'perc_of_values_mode': 0.35974304068522484,
#      'mode': 20.0,
#      'kurtosis': 1.5806307806274136,
#      'target_slope': -209.28573543648187,
#      'target_intercept': 194283.71810002887,
#      'target_r_value': -0.1129103792613073,
#      'target_p_value': 0.0005459399735966862,
#      'target_std_err': 60.32698926148947}],
#    'general_description': {'rows': 934,
#     'columns': 87,
#     'feature_columns_size': 3,
#     'mean_nan_count': 0,
#     'mean_mean': -2191659908351.045,
#     'mean_min': -6574983617946.038,
#     'mean_max': 3892935.1809421843,
#     'mean_median': -42.27730192719486,
#     'mean_skew': -1.7320508075668282,
#     'mean_perc_unique': 0.6666666666666666,
#     'mean_perc_of_values_mode': 0.3333333333333333,
#     'mean_mode': 3892935.1809421843,
#     'mean_kurtosis': -1.4999999999999998,
#     'min_nan_count': 0,
#     'min_mean': -2047011565202404.2,
#     'min_min': -6141034699161600.0,
#     'min_max': 3554928.0,
#     'min_median': -541.0,
#     'min_skew': -1.732050807568878,
#     'min_perc_unique': 0.6666666666666666,
#     'min_perc_of_values_mode': 0.3333333333333333,
#     'min_mode': -6141034699161600.0,
#     'min_kurtosis': -1.5000000000000002,
#     'max_nan_count': 0,
#     'max_mean': 1346703.3333333333,
#     'max_min': 0.0,
#     'max_max': 4040100.0,
#     'max_median': 10.0,
#     'max_skew': 1.732050807533064,
#     'max_perc_unique': 0.6666666666666666,
#     'max_perc_of_values_mode': 0.3333333333333333,
#     'max_mode': 0.0,
#     'max_kurtosis': -1.5000000000000002,
#     'median_nan_count': 0,
#     'median_mean': 1301376.3333333333,
#     'median_min': -22.0,
#     'median_max': 3904151.0,
#     'median_median': 0.0,
#     'median_skew': 1.7320508073832581,
#     'median_perc_unique': 0.6666666666666666,
#     'median_perc_of_values_mode': 0.3333333333333333,
#     'median_mode': 0.0,
#     'median_kurtosis': -1.5,
#     'skew_nan_count': 0,
#     'skew_mean': -11.2223691021305,
#     'skew_min': -30.56141357987226,
#     'skew_max': -0.5362217654365666,
#     'skew_median': -2.569471961082673,
#     'skew_skew': -1.7034814243634795,
#     'skew_perc_unique': 0.6666666666666666,
#     'skew_perc_of_values_mode': 0.3333333333333333,
#     'skew_mode': -0.5362217654365666,
#     'skew_kurtosis': -1.5000000000000002,
#     'perc_unique_nan_count': 0,
#     'perc_unique_mean': 0.17237687366167023,
#     'perc_unique_min': 0.0010706638115631692,
#     'perc_unique_max': 0.3083511777301927,
#     'perc_unique_median': 0.20770877944325483,
#     'perc_unique_skew': -0.9632867442486486,
#     'perc_unique_perc_unique': 0.6666666666666666,
#     'perc_unique_perc_of_values_mode': 0.3333333333333333,
#     'perc_unique_mode': 0.0010706638115631692,
#     'perc_unique_kurtosis': -1.5000000000000004,
#     'perc_of_values_mode_nan_count': 0,
#     'perc_of_values_mode_mean': 0.40685224839400425,
#     'perc_of_values_mode_min': 0.048179871520342615,
#     'perc_of_values_mode_max': 0.9989293361884368,
#     'perc_of_values_mode_median': 0.1734475374732334,
#     'perc_of_values_mode_skew': 1.6181666583739944,
#     'perc_of_values_mode_perc_unique': 0.6666666666666666,
#     'perc_of_values_mode_perc_of_values_mode': 0.3333333333333333,
#     'perc_of_values_mode_mode': 0.9989293361884368,
#     'perc_of_values_mode_kurtosis': -1.4999999999999998,
#     'mode_nan_count': 0,
#     'mode_mean': 1340010.0,
#     'mode_min': 0.0,
#     'mode_max': 4020025.0,
#     'mode_median': 5.0,
#     'mode_skew': 1.7320508075598344,
#     'mode_perc_unique': 0.6666666666666666,
#     'mode_perc_of_values_mode': 0.3333333333333333,
#     'mode_mode': 4020025.0,
#     'mode_kurtosis': -1.4999999999999998,
#     'kurtosis_nan_count': 0,
#     'kurtosis_mean': 312.6688220068064,
#     'kurtosis_min': -0.6407917345169745,
#     'kurtosis_max': 929.0010718113616,
#     'kurtosis_median': 9.646185943574606,
#     'kurtosis_skew': 1.7313271375732109,
#     'kurtosis_perc_unique': 0.6666666666666666,
#     'kurtosis_perc_of_values_mode': 0.3333333333333333,
#     'kurtosis_mode': 9.646185943574606,
#     'kurtosis_kurtosis': -1.5000000000000002,
#     'target_slope_nan_count': 0,
#     'target_slope_mean': -101.69880402419813,
#     'target_slope_min': -305.4805668256009,
#     'target_slope_max': 0.3841547530150552,
#     'target_slope_median': -8.59571134427232e-12,
#     'target_slope_skew': -1.732041574779041,
#     'target_slope_perc_unique': 0.6666666666666666,
#     'target_slope_perc_of_values_mode': 0.3333333333333333,
#     'target_slope_mode': -8.59571134427232e-12,
#     'target_slope_kurtosis': -1.4999999999999996,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': -320550.36621998466,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 182213.43837084674,
#     'target_intercept_median': 169355.06087554336,
#     'target_intercept_skew': -1.7316149137625894,
#     'target_intercept_perc_unique': 0.6666666666666666,
#     'target_intercept_perc_of_values_mode': 0.3333333333333333,
#     'target_intercept_mode': -1313219.597906344,
#     'target_intercept_kurtosis': -1.5,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': 0.08495418228299585,
#     'target_r_value_min': -0.2695308435885969,
#     'target_r_value_max': 0.5462599137534613,
#     'target_r_value_median': -0.021866523315876813,
#     'target_r_value_skew': 1.074319701073197,
#     'target_r_value_perc_unique': 0.6666666666666666,
#     'target_r_value_perc_of_values_mode': 0.3333333333333333,
#     'target_r_value_mode': -0.021866523315876813,
#     'target_r_value_kurtosis': -1.4999999999999996,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 0.16816014300673823,
#     'target_p_value_min': 9.044925393388627e-74,
#     'target_p_value_max': 0.5044804290202147,
#     'target_p_value_median': 5.2119041110286685e-17,
#     'target_p_value_skew': 1.7320508075688785,
#     'target_p_value_perc_unique': 0.6666666666666666,
#     'target_p_value_perc_of_values_mode': 0.3333333333333333,
#     'target_p_value_mode': 5.2119041110286685e-17,
#     'target_p_value_kurtosis': -1.4999999999999996,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 11.923473818340161,
#     'target_std_err_min': 1.287331145005518e-11,
#     'target_std_err_max': 35.751126501069926,
#     'target_std_err_median': 0.01929495393767906,
#     'target_std_err_skew': 1.7320491039332186,
#     'target_std_err_perc_unique': 0.6666666666666666,
#     'target_std_err_perc_of_values_mode': 0.3333333333333333,
#     'target_std_err_mode': 1.287331145005518e-11,
#     'target_std_err_kurtosis': -1.5000000000000007},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'dictionary_encode',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 60.889721627408996,
#      'min': 20.0,
#      'max': 313.0,
#      'median': 62.0,
#      'skew': 1.4340299707995783,
#      'perc_unique': 0.10813704496788008,
#      'perc_of_values_mode': 0.18522483940042828,
#      'mode': 20.0,
#      'kurtosis': 9.67435237063386,
#      'target_slope': 605.7815989177714,
#      'target_intercept': 145384.08210701006,
#      'target_r_value': 0.2328192250866186,
#      'target_p_value': 5.804752736910327e-13,
#      'target_std_err': 82.88727009726222}],
#    'general_description': {'rows': 934,
#     'columns': 88,
#     'feature_columns_size': 4,
#     'mean_nan_count': 0,
#     'mean_mean': -1643744931262.668,
#     'mean_min': -6574983617946.038,
#     'mean_max': 3892935.1809421843,
#     'mean_median': -19.907387580299787,
#     'mean_skew': -1.9999999999981302,
#     'mean_perc_unique': 0.75,
#     'mean_perc_of_values_mode': 0.25,
#     'mean_mode': 3892935.1809421843,
#     'mean_kurtosis': -0.6666666666674979,
#     'min_nan_count': 0,
#     'min_mean': -1535258673901803.2,
#     'min_min': -6141034699161600.0,
#     'min_max': 3554928.0,
#     'min_median': -270.5,
#     'min_skew': -2.0,
#     'min_perc_unique': 0.75,
#     'min_perc_of_values_mode': 0.25,
#     'min_mode': -6141034699161600.0,
#     'min_kurtosis': -0.6666666666666661,
#     'max_nan_count': 0,
#     'max_mean': 1010031.0,
#     'max_min': 0.0,
#     'max_max': 4040100.0,
#     'max_median': 12.0,
#     'max_skew': 1.9999999999490266,
#     'max_perc_unique': 0.75,
#     'max_perc_of_values_mode': 0.25,
#     'max_mode': 14.0,
#     'max_kurtosis': -0.6666666666893208,
#     'median_nan_count': 0,
#     'median_mean': 976032.5,
#     'median_min': -22.0,
#     'median_max': 3904151.0,
#     'median_median': 0.5,
#     'median_skew': 1.9999999998226003,
#     'median_perc_unique': 0.75,
#     'median_perc_of_values_mode': 0.25,
#     'median_mode': 3904151.0,
#     'median_kurtosis': -0.6666666667455106,
#     'skew_nan_count': 0,
#     'skew_mean': -8.063145789293142,
#     'skew_min': -30.56141357987226,
#     'skew_max': 1.4145241492189307,
#     'skew_median': -1.55284686325962,
#     'skew_skew': -1.9306244243674513,
#     'skew_perc_unique': 0.75,
#     'skew_perc_of_values_mode': 0.25,
#     'skew_mode': -0.5362217654365666,
#     'skew_kurtosis': -0.6974329439669673,
#     'perc_unique_nan_count': 0,
#     'perc_unique_mean': 0.13302997858672377,
#     'perc_unique_min': 0.0010706638115631692,
#     'perc_unique_max': 0.3083511777301927,
#     'perc_unique_median': 0.1113490364025696,
#     'perc_unique_skew': 0.36665392077472875,
#     'perc_unique_perc_unique': 0.75,
#     'perc_unique_perc_of_values_mode': 0.25,
#     'perc_unique_mode': 0.3083511777301927,
#     'perc_unique_kurtosis': -1.7127590113503044,
#     'perc_of_values_mode_nan_count': 0,
#     'perc_of_values_mode_mean': 0.3950749464668094,
#     'perc_of_values_mode_min': 0.048179871520342615,
#     'perc_of_values_mode_max': 0.9989293361884368,
#     'perc_of_values_mode_median': 0.26659528907922914,
#     'perc_of_values_mode_skew': 1.4814827070657883,
#     'perc_of_values_mode_perc_unique': 0.75,
#     'perc_of_values_mode_perc_of_values_mode': 0.25,
#     'perc_of_values_mode_mode': 0.9989293361884368,
#     'perc_of_values_mode_kurtosis': -0.9084251909168928,
#     'mode_nan_count': 0,
#     'mode_mean': 1005007.5,
#     'mode_min': 0.0,
#     'mode_max': 4020025.0,
#     'mode_median': 2.5,
#     'mode_skew': 1.99999999999175,
#     'mode_perc_unique': 0.5,
#     'mode_perc_of_values_mode': 0.5,
#     'mode_mode': 0.0,
#     'mode_kurtosis': -0.6666666666703338,
#     'kurtosis_nan_count': 0,
#     'kurtosis_mean': 234.8112389631135,
#     'kurtosis_min': -0.6407917345169745,
#     'kurtosis_max': 929.0010718113616,
#     'kurtosis_median': 5.4423378878046975,
#     'kurtosis_skew': 1.9994407649655948,
#     'kurtosis_perc_unique': 0.75,
#     'kurtosis_perc_of_values_mode': 0.25,
#     'kurtosis_mode': 929.0010718113616,
#     'kurtosis_kurtosis': -0.6669171763155295,
#     'target_slope_nan_count': 0,
#     'target_slope_mean': -1822.7764302421879,
#     'target_slope_min': -6986.009308896157,
#     'target_slope_max': 0.3841547530150552,
#     'target_slope_median': -152.74028341280473,
#     'target_slope_skew': -1.9896141870190087,
#     'target_slope_perc_unique': 0.75,
#     'target_slope_perc_of_values_mode': 0.25,
#     'target_slope_mode': -6986.009308896157,
#     'target_slope_kurtosis': -0.6714623379347961,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': -190544.47717824837,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 199473.18994696054,
#     'target_intercept_median': 175784.24962319504,
#     'target_intercept_skew': -1.9983681881235402,
#     'target_intercept_perc_unique': 0.75,
#     'target_intercept_perc_of_values_mode': 0.25,
#     'target_intercept_mode': 182213.43837084674,
#     'target_intercept_kurtosis': -0.6673890045592494,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': -0.005109469434871061,
#     'target_r_value_min': -0.2753004245884718,
#     'target_r_value_max': 0.5462599137534613,
#     'target_r_value_median': -0.14569868345223685,
#     'target_r_value_skew': 1.4988826132562785,
#     'target_r_value_perc_unique': 0.75,
#     'target_r_value_perc_of_values_mode': 0.25,
#     'target_r_value_mode': -0.2753004245884718,
#     'target_r_value_kurtosis': -0.9471915923247187,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 0.12612010725505368,
#     'target_p_value_min': 9.044925393388627e-74,
#     'target_p_value_max': 0.5044804290202147,
#     'target_p_value_median': 3.1305668477298594e-17,
#     'target_p_value_skew': 2.0,
#     'target_p_value_perc_unique': 0.75,
#     'target_p_value_perc_of_values_mode': 0.25,
#     'target_p_value_mode': 0.5044804290202147,
#     'target_p_value_kurtosis': -0.666666666666667,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 208.71689123457784,
#     'target_std_err_min': 1.287331145005518e-11,
#     'target_std_err_max': 799.0971434832909,
#     'target_std_err_median': 17.885210727503804,
#     'target_std_err_skew': 1.989143090011717,
#     'target_std_err_perc_unique': 0.75,
#     'target_std_err_perc_of_values_mode': 0.25,
#     'target_std_err_mode': 0.01929495393767906,
#     'target_std_err_kurtosis': -0.6716840526038652},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'power_transform',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'string',
#      'nan_count': 0,
#      'nunique': 6,
#      'perc_of_values_mode': 0.9764453961456103,
#      'mode': 'GasA',
#      'target_p_value': 0.01884224298034687,
#      'target_f_stat': 2.722598048263465}],
#    'general_description': {'rows': 934,
#     'columns': 89,
#     'feature_columns_size': 5,
#     'mean_nan_count': 0,
#     'mean_mean': -1314995945010.1343,
#     'mean_min': -6574983617946.038,
#     'mean_max': 3892935.1809421843,
#     'mean_median': -2.320294800929663e-16,
#     'mean_skew': -2.236067977497953,
#     'mean_perc_unique': 0.8,
#     'mean_perc_of_values_mode': 0.2,
#     'mean_mode': 3892935.1809421843,
#     'mean_kurtosis': 0.24999999999835776,
#     'min_nan_count': 0,
#     'min_mean': -1228206939121443.0,
#     'min_min': -6141034699161600.0,
#     'min_max': 3554928.0,
#     'min_median': -1.5667941372620928,
#     'min_skew': -2.236067977499789,
#     'min_perc_unique': 0.8,
#     'min_perc_of_values_mode': 0.2,
#     'min_mode': -6141034699161600.0,
#     'min_kurtosis': 0.2499999999999991,
#     'max_nan_count': 0,
#     'max_mean': 808025.8303047678,
#     'max_min': 0.0,
#     'max_max': 4040100.0,
#     'max_median': 10.0,
#     'max_skew': 2.2360679774526617,
#     'max_perc_unique': 0.8,
#     'max_perc_of_values_mode': 0.2,
#     'max_mode': 5.151523839210007,
#     'max_kurtosis': 0.2499999999578475,
#     'median_nan_count': 0,
#     'median_mean': 780826.0327368703,
#     'median_min': -22.0,
#     'median_max': 3904151.0,
#     'median_median': 0.16368435196960088,
#     'median_skew': 2.2360679773271923,
#     'median_perc_unique': 0.8,
#     'median_perc_of_values_mode': 0.2,
#     'median_mode': 3904151.0,
#     'median_kurtosis': 0.24999999984562438,
#     'skew_nan_count': 0,
#     'skew_mean': -6.45099913775852,
#     'skew_min': -30.56141357987226,
#     'skew_max': 1.4145241492189307,
#     'skew_median': -0.5362217654365666,
#     'skew_skew': -2.174732386641892,
#     'skew_perc_unique': 0.8,
#     'skew_perc_of_values_mode': 0.2,
#     'skew_mode': 1.4145241492189307,
#     'skew_kurtosis': 0.19409811729484128,
#     'perc_unique_nan_count': 0,
#     'perc_unique_mean': 0.12805139186295506,
#     'perc_unique_min': 0.0010706638115631692,
#     'perc_unique_max': 0.3083511777301927,
#     'perc_unique_median': 0.10813704496788008,
#     'perc_unique_skew': 0.5368967147807695,
#     'perc_unique_perc_unique': 0.8,
#     'perc_unique_perc_of_values_mode': 0.2,
#     'perc_unique_mode': 0.3083511777301927,
#     'perc_unique_kurtosis': -1.3633381058579144,
#     'perc_of_values_mode_nan_count': 0,
#     'perc_of_values_mode_mean': 0.3531049250535332,
#     'perc_of_values_mode_min': 0.048179871520342615,
#     'perc_of_values_mode_max': 0.9989293361884368,
#     'perc_of_values_mode_median': 0.18522483940042828,
#     'perc_of_values_mode_skew': 1.782600370849499,
#     'perc_of_values_mode_perc_unique': 0.8,
#     'perc_of_values_mode_perc_of_values_mode': 0.2,
#     'perc_of_values_mode_mode': 0.9989293361884368,
#     'perc_of_values_mode_kurtosis': -0.16721527948842185,
#     'mode_nan_count': 0,
#     'mode_mean': 804005.6866411725,
#     'mode_min': -1.5667941372620928,
#     'mode_max': 4020025.0,
#     'mode_median': 0.0,
#     'mode_skew': 2.236067977489193,
#     'mode_perc_unique': 0.6,
#     'mode_perc_of_values_mode': 0.4,
#     'mode_mode': 0.0,
#     'mode_kurtosis': 0.24999999999052225,
#     'kurtosis_nan_count': 0,
#     'kurtosis_mean': 187.98778700683982,
#     'kurtosis_min': -0.6407917345169745,
#     'kurtosis_max': 929.0010718113616,
#     'kurtosis_median': 1.23848983203479,
#     'kurtosis_skew': 2.235535688139374,
#     'kurtosis_perc_unique': 0.8,
#     'kurtosis_perc_of_values_mode': 0.2,
#     'kurtosis_mode': 0.6939791817450369,
#     'kurtosis_kurtosis': 0.2495202637176548,
#     'target_slope_nan_count': 0,
#     'target_slope_mean': 1941.1188826136513,
#     'target_slope_min': -6986.009308896157,
#     'target_slope_max': 16996.700134037008,
#     'target_slope_median': -8.59571134427232e-12,
#     'target_slope_skew': 1.5655584788288794,
#     'target_slope_perc_unique': 0.8,
#     'target_slope_perc_of_values_mode': 0.2,
#     'target_slope_mode': -6986.009308896157,
#     'target_slope_kurtosis': -0.15980983858864706,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': -115981.59073617472,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 199473.18994696054,
#     'target_intercept_median': 182213.43837084674,
#     'target_intercept_skew': -2.2346366113058087,
#     'target_intercept_perc_unique': 0.8,
#     'target_intercept_perc_of_values_mode': 0.2,
#     'target_intercept_mode': 182213.43837084674,
#     'target_intercept_kurtosis': 0.24872450338913898,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': 0.03897073897684805,
#     'target_r_value_min': -0.2753004245884718,
#     'target_r_value_max': 0.5462599137534613,
#     'target_r_value_median': -0.021866523315876813,
#     'target_r_value_skew': 0.7416788986697882,
#     'target_r_value_perc_unique': 0.8,
#     'target_r_value_perc_of_values_mode': 0.2,
#     'target_r_value_mode': -0.2753004245884718,
#     'target_r_value_kurtosis': -1.1796366432025343,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 0.1008960858099478,
#     'target_p_value_min': 9.044925393388627e-74,
#     'target_p_value_max': 0.5044804290202147,
#     'target_p_value_median': 5.2119041110286685e-17,
#     'target_p_value_skew': 2.2360679774997902,
#     'target_p_value_perc_unique': 0.8,
#     'target_p_value_perc_of_values_mode': 0.2,
#     'target_p_value_mode': 2.952432695464162e-11,
#     'target_p_value_kurtosis': 0.2500000000000009,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 672.0463623863716,
#     'target_std_err_min': 1.287331145005518e-11,
#     'target_std_err_max': 2525.3642469935467,
#     'target_std_err_median': 35.751126501069926,
#     'target_std_err_skew': 1.7668833225343055,
#     'target_std_err_perc_unique': 0.8,
#     'target_std_err_perc_of_values_mode': 0.2,
#     'target_std_err_mode': 0.01929495393767906,
#     'target_std_err_kurtosis': -0.2691859517823878},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'dictionary_encode',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 1974.252676659529,
#      'min': 1899.0,
#      'max': 2010.0,
#      'median': 1978.0,
#      'skew': -0.9238021214428892,
#      'perc_unique': 0.10278372591006424,
#      'perc_of_values_mode': 0.055674518201284794,
#      'mode': 1899.0,
#      'kurtosis': 0.0991245085967205,
#      'target_slope': 1323.5346075041834,
#      'target_intercept': -2430721.7864845335,
#      'target_r_value': 0.5082238739123109,
#      'target_p_value': 1.7315342073400314e-62,
#      'target_std_err': 73.46642544084692}],
#    'general_description': {'rows': 934,
#     'columns': 90,
#     'feature_columns_size': 6,
#     'mean_nan_count': 0,
#     'mean_mean': -1095829954175.1045,
#     'mean_min': -6574983617946.038,
#     'mean_max': 3892935.1809421843,
#     'mean_median': 0.022483940042826438,
#     'mean_skew': -2.449489742781324,
#     'mean_perc_unique': 0.8333333333333334,
#     'mean_perc_of_values_mode': 0.16666666666666666,
#     'mean_mode': 3892935.1809421843,
#     'mean_kurtosis': 1.1999999999975772,
#     'min_nan_count': 0,
#     'min_mean': -1023505782601202.5,
#     'min_min': -6141034699161600.0,
#     'min_max': 3554928.0,
#     'min_median': -0.7833970686310464,
#     'min_skew': -2.4494897427831788,
#     'min_perc_unique': 0.6666666666666666,
#     'min_perc_of_values_mode': 0.3333333333333333,
#     'min_mode': 0.0,
#     'min_kurtosis': 1.200000000000002,
#     'max_nan_count': 0,
#     'max_mean': 673355.6919206398,
#     'max_min': 0.0,
#     'max_max': 4040100.0,
#     'max_median': 7.575761919605004,
#     'max_skew': 2.449489742736876,
#     'max_perc_unique': 0.8333333333333334,
#     'max_perc_of_values_mode': 0.16666666666666666,
#     'max_mode': 5.0,
#     'max_kurtosis': 1.1999999999395117,
#     'median_nan_count': 0,
#     'median_mean': 650688.3606140587,
#     'median_min': -22.0,
#     'median_max': 3904151.0,
#     'median_median': 0.08184217598480044,
#     'median_skew': 2.449489742610402,
#     'median_perc_unique': 0.6666666666666666,
#     'median_perc_of_values_mode': 0.3333333333333333,
#     'median_mode': 0.0,
#     'median_kurtosis': 1.1999999997742865,
#     'skew_nan_count': 0,
#     'skew_mean': -3.7727659231212347,
#     'skew_min': -30.56141357987226,
#     'skew_max': 9.618400150065188,
#     'skew_median': -0.26931714852829813,
#     'skew_skew': -1.9008432223939271,
#     'skew_perc_unique': 0.8333333333333334,
#     'skew_perc_of_values_mode': 0.16666666666666666,
#     'skew_mode': 1.4145241492189307,
#     'skew_kurtosis': 0.6444636647878452,
#     'perc_unique_nan_count': 0,
#     'perc_unique_mean': 0.10760171306209852,
#     'perc_unique_min': 0.0010706638115631692,
#     'perc_unique_max': 0.3083511777301927,
#     'perc_unique_median': 0.06156316916488223,
#     'perc_unique_skew': 0.8808951291041955,
#     'perc_unique_perc_unique': 0.8333333333333334,
#     'perc_unique_perc_of_values_mode': 0.16666666666666666,
#     'perc_unique_mode': 0.0053533190578158455,
#     'perc_unique_kurtosis': -1.1241516087355734,
#     'perc_of_values_mode_nan_count': 0,
#     'perc_of_values_mode_mean': 0.4569950035688794,
#     'perc_of_values_mode_min': 0.048179871520342615,
#     'perc_of_values_mode_max': 0.9989293361884368,
#     'perc_of_values_mode_median': 0.27248394004282656,
#     'perc_of_values_mode_skew': 0.7423893948995305,
#     'perc_of_values_mode_perc_unique': 0.8333333333333334,
#     'perc_of_values_mode_perc_of_values_mode': 0.16666666666666666,
#     'perc_of_values_mode_mode': 0.9989293361884368,
#     'perc_of_values_mode_kurtosis': -1.5072705819199983,
#     'mode_nan_count': 0,
#     'mode_mean': 670004.7388676438,
#     'mode_min': -1.5667941372620928,
#     'mode_max': 4020025.0,
#     'mode_median': 0.0,
#     'mode_skew': 2.449489742772907,
#     'mode_perc_unique': 0.5,
#     'mode_perc_of_values_mode': 0.5,
#     'mode_mode': 0.0,
#     'mode_kurtosis': 1.1999999999865825,
#     'kurtosis_nan_count': 0,
#     'kurtosis_mean': 173.99444110464705,
#     'kurtosis_min': -0.6407917345169745,
#     'kurtosis_max': 929.0010718113616,
#     'kurtosis_median': 5.4423378878046975,
#     'kurtosis_skew': 2.3867701012163747,
#     'kurtosis_perc_unique': 0.8333333333333334,
#     'kurtosis_perc_of_values_mode': 0.16666666666666666,
#     'kurtosis_mode': 0.6939791817450369,
#     'kurtosis_kurtosis': 1.111187779833,
#     'target_slope_nan_count': 0,
#     'target_slope_mean': -2535.710490617515,
#     'target_slope_min': -24919.857356773347,
#     'target_slope_max': 16996.700134037008,
#     'target_slope_median': -152.74028341280473,
#     'target_slope_skew': -0.4575694456830791,
#     'target_slope_perc_unique': 0.8333333333333334,
#     'target_slope_perc_of_values_mode': 0.16666666666666666,
#     'target_slope_mode': -6986.009308896157,
#     'target_slope_kurtosis': -0.18624538287849957,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': -66086.2342485638,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 199473.18994696054,
#     'target_intercept_median': 182241.69670148334,
#     'target_intercept_skew': -2.448135017209648,
#     'target_intercept_perc_unique': 0.8333333333333334,
#     'target_intercept_perc_of_values_mode': 0.16666666666666666,
#     'target_intercept_mode': 182213.43837084674,
#     'target_intercept_kurtosis': 1.1982354308217307,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': 0.014412223139701199,
#     'target_r_value_min': -0.2753004245884718,
#     'target_r_value_max': 0.5462599137534613,
#     'target_r_value_median': -0.06512343968095494,
#     'target_r_value_skew': 1.025371057339123,
#     'target_r_value_perc_unique': 0.8333333333333334,
#     'target_r_value_perc_of_values_mode': 0.16666666666666666,
#     'target_r_value_mode': -0.2753004245884718,
#     'target_r_value_kurtosis': -0.7477661423465971,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 0.08423139654997319,
#     'target_p_value_min': 9.044925393388627e-74,
#     'target_p_value_max': 0.5044804290202147,
#     'target_p_value_median': 1.4762189536841364e-11,
#     'target_p_value_skew': 2.4494726046758513,
#     'target_p_value_perc_unique': 0.8333333333333334,
#     'target_p_value_perc_of_values_mode': 0.16666666666666666,
#     'target_p_value_mode': 2.952432695464162e-11,
#     'target_p_value_kurtosis': 1.199977578642832,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 1807.9105095107934,
#     'target_std_err_min': 1.287331145005518e-11,
#     'target_std_err_max': 7487.231245132903,
#     'target_std_err_median': 417.4241349921804,
#     'target_std_err_skew': 1.9330046574502784,
#     'target_std_err_perc_unique': 0.8333333333333334,
#     'target_std_err_perc_of_values_mode': 0.16666666666666666,
#     'target_std_err_mode': 7487.231245132903,
#     'target_std_err_kurtosis': 0.40749464717250294},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'quantile_scaler',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 50.856531049250535,
#      'min': 0.0,
#      'max': 15500.0,
#      'median': 0.0,
#      'skew': 20.822893692109247,
#      'perc_unique': 0.016059957173447537,
#      'perc_of_values_mode': 0.9689507494646681,
#      'mode': 0.0,
#      'kurtosis': 486.85845212136337,
#      'target_slope': -2.875494711290692,
#      'target_intercept': 182416.19271818662,
#      'target_r_value': -0.02208198045107555,
#      'target_p_value': 0.50028907098659,
#      'target_std_err': 4.264427016610474}],
#    'general_description': {'rows': 934,
#     'columns': 91,
#     'feature_columns_size': 7,
#     'mean_nan_count': 0,
#     'mean_mean': -939282817864.3041,
#     'mean_min': -6574983617946.038,
#     'mean_max': 3892935.1809421843,
#     'mean_median': 0.044967880085653104,
#     'mean_skew': -2.6457513110626967,
#     'mean_perc_unique': 0.8571428571428571,
#     'mean_perc_of_values_mode': 0.14285714285714285,
#     'mean_mode': 3892935.1809421843,
#     'mean_kurtosis': 2.1666666666634864,
#     'min_nan_count': 0,
#     'min_mean': -877290670801030.8,
#     'min_min': -6141034699161600.0,
#     'min_max': 3554928.0,
#     'min_median': 0.0,
#     'min_skew': -2.64575131106459,
#     'min_perc_unique': 0.5714285714285714,
#     'min_perc_of_values_mode': 0.42857142857142855,
#     'min_mode': 0.0,
#     'min_kurtosis': 2.166666666666666,
#     'max_nan_count': 0,
#     'max_mean': 577162.1645034056,
#     'max_min': 0.0,
#     'max_max': 4040100.0,
#     'max_median': 5.151523839210007,
#     'max_skew': 2.6457513110079587,
#     'max_perc_unique': 0.8571428571428571,
#     'max_perc_of_values_mode': 0.14285714285714285,
#     'max_mode': 5.151523839210007,
#     'max_kurtosis': 2.166666666571535,
#     'median_nan_count': 0,
#     'median_mean': 557732.9524142551,
#     'median_min': -22.0,
#     'median_max': 3904151.0,
#     'median_median': 0.16368435196960088,
#     'median_skew': 2.6457513108875186,
#     'median_perc_unique': 0.7142857142857143,
#     'median_perc_of_values_mode': 0.2857142857142857,
#     'median_mode': 0.0,
#     'median_kurtosis': 2.1666666663692133,
#     'skew_nan_count': 0,
#     'skew_mean': -3.2378696689633695,
#     'skew_min': -30.56141357987226,
#     'skew_max': 9.618400150065188,
#     'skew_median': -0.028492144016176578,
#     'skew_skew': -2.078661511458531,
#     'skew_perc_unique': 0.8571428571428571,
#     'skew_perc_of_values_mode': 0.14285714285714285,
#     'skew_mode': 9.618400150065188,
#     'skew_kurtosis': 1.4280020068300727,
#     'perc_unique_nan_count': 0,
#     'perc_unique_mean': 0.10691342918323647,
#     'perc_unique_min': 0.0010706638115631692,
#     'perc_unique_max': 0.3083511777301927,
#     'perc_unique_median': 0.10278372591006424,
#     'perc_unique_skew': 0.9252141192265267,
#     'perc_unique_perc_unique': 0.8571428571428571,
#     'perc_unique_perc_of_values_mode': 0.14285714285714285,
#     'perc_unique_mode': 0.0053533190578158455,
#     'perc_unique_kurtosis': -0.7945341871402611,
#     'perc_of_values_mode_nan_count': 0,
#     'perc_of_values_mode_mean': 0.399663505659223,
#     'perc_of_values_mode_min': 0.048179871520342615,
#     'perc_of_values_mode_max': 0.9989293361884368,
#     'perc_of_values_mode_median': 0.18522483940042828,
#     'perc_of_values_mode_skew': 0.9854972717270741,
#     'perc_of_values_mode_perc_unique': 0.8571428571428571,
#     'perc_of_values_mode_perc_of_values_mode': 0.14285714285714285,
#     'perc_of_values_mode_mode': 0.18522483940042828,
#     'perc_of_values_mode_kurtosis': -1.202916161208973,
#     'mode_nan_count': 0,
#     'mode_mean': 574289.7761722661,
#     'mode_min': -1.5667941372620928,
#     'mode_max': 4020025.0,
#     'mode_median': 0.0,
#     'mode_skew': 2.645751311054366,
#     'mode_perc_unique': 0.42857142857142855,
#     'mode_perc_of_values_mode': 0.5714285714285714,
#     'mode_mode': 0.0,
#     'mode_kurtosis': 2.1666666666494905,
#     'kurtosis_nan_count': 0,
#     'kurtosis_mean': 148.97095651877095,
#     'kurtosis_min': -1.1699509964854875,
#     'kurtosis_max': 929.0010718113616,
#     'kurtosis_median': 1.23848983203479,
#     'kurtosis_skew': 2.5815913431608024,
#     'kurtosis_perc_unique': 0.8571428571428571,
#     'kurtosis_perc_of_values_mode': 0.14285714285714285,
#     'kurtosis_mode': -1.1699509964854875,
#     'kurtosis_kurtosis': 2.0500838148087395,
#     'target_slope_nan_count': 0,
#     'target_slope_mean': 19191.202878630986,
#     'target_slope_min': -24919.857356773347,
#     'target_slope_max': 149552.68309412198,
#     'target_slope_median': -8.59571134427232e-12,
#     'target_slope_skew': 2.398490638691688,
#     'target_slope_perc_unique': 0.8571428571428571,
#     'target_slope_perc_of_values_mode': 0.14285714285714285,
#     'target_slope_mode': -6986.009308896157,
#     'target_slope_kurtosis': 1.7727300245894373,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': -41256.46873405847,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 199473.18994696054,
#     'target_intercept_median': 182213.43837084674,
#     'target_intercept_skew': -2.630723632148684,
#     'target_intercept_perc_unique': 0.8571428571428571,
#     'target_intercept_perc_of_values_mode': 0.14285714285714285,
#     'target_intercept_mode': -1313219.597906344,
#     'target_intercept_kurtosis': 2.140606931294503,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': 0.09122076192840116,
#     'target_r_value_min': -0.2753004245884718,
#     'target_r_value_max': 0.552071994660601,
#     'target_r_value_median': -0.021866523315876813,
#     'target_r_value_skew': 0.4650376794316333,
#     'target_r_value_perc_unique': 0.8571428571428571,
#     'target_r_value_perc_of_values_mode': 0.14285714285714285,
#     'target_r_value_mode': 0.552071994660601,
#     'target_r_value_kurtosis': -1.4530796245120154,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 0.07219833989997702,
#     'target_p_value_min': 1.2648015798485345e-75,
#     'target_p_value_max': 0.5044804290202147,
#     'target_p_value_median': 5.2119041110286685e-17,
#     'target_p_value_skew': 2.6457338174138334,
#     'target_p_value_perc_unique': 0.8571428571428571,
#     'target_p_value_perc_of_values_mode': 0.14285714285714285,
#     'target_p_value_mode': 0.5044804290202147,
#     'target_p_value_kurtosis': 2.1666372389745865,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 2606.582936651693,
#     'target_std_err_min': 1.287331145005518e-11,
#     'target_std_err_max': 7487.231245132903,
#     'target_std_err_median': 799.0971434832909,
#     'target_std_err_skew': 0.9782690292415932,
#     'target_std_err_perc_unique': 0.8571428571428571,
#     'target_std_err_perc_of_values_mode': 0.14285714285714285,
#     'target_std_err_mode': 7398.617499497093,
#     'target_std_err_kurtosis': -1.2394049657117496},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'quantile_scaler',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 22.298715203426124,
#      'min': 0.0,
#      'max': 552.0,
#      'median': 0.0,
#      'skew': 3.210972194379572,
# ...
#     'target_slope_mean': 11836.436599921137,
#     'target_slope_min': -27881.06669950838,
#     'target_slope_max': 149552.68309412198,
#     'target_slope_median': -8.59571134427232e-12,
#     'target_slope_skew': 2.6191852502196338,
#     'target_slope_perc_unique': 0.8888888888888888,
#     'target_slope_perc_of_values_mode': 0.1111111111111111,
#     'target_slope_mode': -6986.009308896157,
#     'target_slope_kurtosis': 3.2830051570018197,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': 2905.701838031592,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 199473.18994696054,
#     'target_intercept_median': 182213.43837084674,
#     'target_intercept_skew': -2.9801733213425283,
#     'target_intercept_perc_unique': 0.8888888888888888,
#     'target_intercept_perc_of_values_mode': 0.1111111111111111,
#     'target_intercept_mode': 183122.58733481044,
#     'target_intercept_kurtosis': 4.077822495699029,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': 0.10828416625593892,
#     'target_r_value_min': -0.2753004245884718,
#     'target_r_value_max': 0.552071994660601,
#     'target_r_value_median': -0.021866523315876813,
#     'target_r_value_skew': 0.3117077408289635,
#     'target_r_value_perc_unique': 0.8888888888888888,
#     'target_r_value_perc_of_values_mode': 0.1111111111111111,
#     'target_r_value_mode': 0.552071994660601,
#     'target_r_value_kurtosis': -1.4626665288396843,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 0.06341097793576524,
#     'target_p_value_min': 1.2648015798485345e-75,
#     'target_p_value_max': 0.5044804290202147,
#     'target_p_value_median': 5.2119041110286685e-17,
#     'target_p_value_skew': 2.9101375917205123,
#     'target_p_value_perc_unique': 0.8888888888888888,
#     'target_p_value_perc_of_values_mode': 0.1111111111111111,
#     'target_p_value_mode': 0.5044804290202147,
#     'target_p_value_kurtosis': 3.8959092772371298,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 3706.737429109921,
#     'target_std_err_min': 1.287331145005518e-11,
#     'target_std_err_max': 15109.201254850372,
#     'target_std_err_median': 799.0971434832909,
#     'target_std_err_skew': 1.489170041242166,
#     'target_std_err_perc_unique': 0.8888888888888888,
#     'target_std_err_perc_of_values_mode': 0.1111111111111111,
#     'target_std_err_mode': 7398.617499497093,
#     'target_std_err_kurtosis': 0.29478540076467086},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'identity',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 1,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 1971.4967880085653,
#      'min': 1872.0,
#      'max': 2010.0,
#      'median': 1974.5,
#      'skew': -0.6562348313020986,
#      'perc_unique': 0.11563169164882227,
#      'perc_of_values_mode': 0.05032119914346895,
#      'mode': 2005.0,
#      'kurtosis': -0.37384078203788107,
#      'target_slope': 1325.6812526850747,
#      'target_intercept': -2431306.376559676,
#      'target_r_value': 0.5131984051783707,
#      'target_p_value': 6.966995251817235e-64,
#      'target_std_err': 72.62226569406046}],
#    'general_description': {'rows': 934,
#     'columns': 94,
#     'feature_columns_size': 10,
#     'mean_nan_count': 0,
#     'mean_mean': -657497972424.3518,
#     'mean_min': -6574983617946.038,
#     'mean_max': 3892935.1809421843,
#     'mean_median': 0.271719958871821,
#     'mean_skew': -3.162277660166327,
#     'mean_perc_unique': 0.9,
#     'mean_perc_of_values_mode': 0.1,
#     'mean_mode': 3892935.1809421843,
#     'mean_kurtosis': 5.111111111105725,
#     'min_nan_count': 0,
#     'min_mean': -614103469560721.5,
#     'min_min': -6141034699161600.0,
#     'min_max': 3554928.0,
#     'min_median': 0.0,
#     'min_skew': -3.162277660168379,
#     'min_perc_unique': 0.4,
#     'min_perc_of_values_mode': 0.6,
#     'min_mode': 0.0,
#     'min_kurtosis': 5.111111111111107,
#     'max_nan_count': 0,
#     'max_mean': 404320.81515238393,
#     'max_min': 0.0,
#     'max_max': 4040100.0,
#     'max_median': 7.575761919605004,
#     'max_skew': 3.162275672285139,
#     'max_perc_unique': 0.8,
#     'max_perc_of_values_mode': 0.2,
#     'max_mode': 1.0,
#     'max_kurtosis': 5.111105893946608,
#     'median_nan_count': 0,
#     'median_mean': 390483.66668997856,
#     'median_min': -22.0,
#     'median_max': 3904151.0,
#     'median_median': 0.08184217598480044,
#     'median_skew': 3.1622774671131024,
#     'median_perc_unique': 0.6,
#     'median_perc_of_values_mode': 0.4,
#     'median_mode': 0.0,
#     'median_kurtosis': 5.11111060455889,
#     'skew_nan_count': 0,
#     'skew_mean': -1.5322396259175715,
#     'skew_min': -30.56141357987226,
#     'skew_max': 9.618400150065188,
#     'skew_median': 0.24917768558571587,
#     'skew_skew': -2.522254085226474,
#     'skew_perc_unique': 0.9,
#     'skew_perc_of_values_mode': 0.1,
#     'skew_mode': 1.4251786122639991,
#     'skew_kurtosis': 3.6860064687119936,
#     'perc_unique_nan_count': 0,
#     'perc_unique_mean': 0.1647751605995717,
#     'perc_unique_min': 0.0010706638115631692,
#     'perc_unique_max': 0.6627408993576017,
#     'perc_unique_median': 0.10546038543897215,
#     'perc_unique_skew': 1.798657007654579,
#     'perc_unique_perc_unique': 0.9,
#     'perc_unique_perc_of_values_mode': 0.1,
#     'perc_unique_mode': 0.0053533190578158455,
#     'perc_unique_kurtosis': 1.516139032571873,
#     'perc_of_values_mode_nan_count': 0,
#     'perc_of_values_mode_mean': 0.43094218415417557,
#     'perc_of_values_mode_min': 0.021413276231263382,
#     'perc_of_values_mode_max': 0.9989293361884368,
#     'perc_of_values_mode_median': 0.27248394004282656,
#     'perc_of_values_mode_skew': 0.5936183759900121,
#     'perc_of_values_mode_perc_unique': 0.9,
#     'perc_of_values_mode_perc_of_values_mode': 0.1,
#     'perc_of_values_mode_mode': 0.18522483940042828,
#     'perc_of_values_mode_kurtosis': -1.4364485564314315,
#     'mode_nan_count': 0,
#     'mode_mean': 402002.84332058625,
#     'mode_min': -1.5667941372620928,
#     'mode_max': 4020025.0,
#     'mode_median': 0.0,
#     'mode_skew': 3.162277660157722,
#     'mode_perc_unique': 0.3,
#     'mode_perc_of_values_mode': 0.7,
#     'mode_mode': 0.0,
#     'mode_kurtosis': 5.111111111083149,
#     'kurtosis_nan_count': 0,
#     'kurtosis_mean': 107.22507936672885,
#     'kurtosis_min': -1.1699509964854875,
#     'kurtosis_max': 929.0010718113616,
#     'kurtosis_median': 1.724238078451342,
#     'kurtosis_skew': 3.093049332472603,
#     'kurtosis_perc_unique': 0.9,
#     'kurtosis_perc_of_values_mode': 0.1,
#     'kurtosis_mode': 27.249750860827504,
#     'kurtosis_kurtosis': 4.9169290359015685,
#     'target_slope_nan_count': 0,
#     'target_slope_mean': 10673.845434227322,
#     'target_slope_min': -27881.06669950838,
#     'target_slope_max': 149552.68309412198,
#     'target_slope_median': 0.19207737650322973,
#     'target_slope_skew': 2.7640979991693566,
#     'target_slope_perc_unique': 0.9,
#     'target_slope_perc_of_values_mode': 0.1,
#     'target_slope_mode': -6986.009308896157,
#     'target_slope_kurtosis': 4.130364174867266,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': 18909.422528310202,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 199473.18994696054,
#     'target_intercept_median': 175784.24962319504,
#     'target_intercept_skew': -3.1421282953291745,
#     'target_intercept_perc_unique': 0.9,
#     'target_intercept_perc_of_values_mode': 0.1,
#     'target_intercept_mode': 183122.58733481044,
#     'target_intercept_kurtosis': 5.057309139481408,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': 0.12960598562125095,
#     'target_r_value_min': -0.2753004245884718,
#     'target_r_value_max': 0.552071994660601,
#     'target_r_value_median': 0.09671252465392384,
#     'target_r_value_skew': 0.08965776517246365,
#     'target_r_value_perc_unique': 0.9,
#     'target_r_value_perc_of_values_mode': 0.1,
#     'target_r_value_mode': 0.552071994660601,
#     'target_r_value_kurtosis': -1.4689795375079633,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 0.05706988014218871,
#     'target_p_value_min': 1.2648015798485345e-75,
#     'target_p_value_max': 0.5044804290202147,
#     'target_p_value_median': 3.1305668477298594e-17,
#     'target_p_value_skew': 3.070393706809154,
#     'target_p_value_perc_unique': 0.9,
#     'target_p_value_perc_of_values_mode': 0.1,
#     'target_p_value_mode': 0.5044804290202147,
#     'target_p_value_kurtosis': 4.848066151386143,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 3338.0947313560196,
#     'target_std_err_min': 1.287331145005518e-11,
#     'target_std_err_max': 15109.201254850372,
#     'target_std_err_median': 417.4241349921804,
#     'target_std_err_skew': 1.6361436526976625,
#     'target_std_err_perc_unique': 0.9,
#     'target_std_err_perc_of_values_mode': 0.1,
#     'target_std_err_mode': 7398.617499497093,
#     'target_std_err_kurtosis': 0.7079520752933233},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'quantile_scaler',
#    'transformation_parameters': {}},
#   {'input_column_descriptions': [{'target': 0,
#      'original_column': 0,
#      'type': 'numeric',
#      'nan_count': 0,
#      'mean': 2.462526766595289,
#      'min': 0.0,
#      'max': 14.0,
#      'median': 1.0,
#      'skew': 1.4145241492189307,
#      'perc_unique': 0.014989293361884369,
#      'perc_of_values_mode': 0.35974304068522484,
#      'mode': 0.0,
#      'kurtosis': 1.23848983203479,
#      'target_slope': -6986.009308896157,
#      'target_intercept': 199473.18994696054,
#      'target_r_value': -0.2753004245884718,
#      'target_p_value': 1.0492295844310504e-17,
#      'target_std_err': 799.0971434832909}],
#    'general_description': {'rows': 934,
#     'columns': 95,
#     'feature_columns_size': 11,
#     'mean_nan_count': 0,
#     'mean_mean': -597725429476.6381,
#     'mean_min': -6574983617946.038,
#     'mean_max': 3892935.1809421843,
#     'mean_median': 0.49847203765798886,
#     'mean_skew': -3.3166247903532904,
#     'mean_perc_unique': 0.9090909090909091,
#     'mean_perc_of_values_mode': 0.09090909090909091,
#     'mean_mode': 3892935.1809421843,
#     'mean_kurtosis': 6.099999999993894,
#     'min_nan_count': 0,
#     'min_mean': -558275881418837.75,
#     'min_min': -6141034699161600.0,
#     'min_max': 3554928.0,
#     'min_median': 0.0,
#     'min_skew': -3.3166247903553994,
#     'min_perc_unique': 0.36363636363636365,
#     'min_perc_of_values_mode': 0.6363636363636364,
#     'min_mode': 0.0,
#     'min_kurtosis': 6.1,
#     'max_nan_count': 0,
#     'max_mean': 367564.468320349,
#     'max_min': 0.0,
#     'max_max': 4040100.0,
#     'max_median': 5.151523839210007,
#     'max_skew': 3.3166227284921015,
#     'max_perc_unique': 0.7272727272727273,
#     'max_perc_of_values_mode': 0.2727272727272727,
#     'max_mode': 1.0,
#     'max_kurtosis': 6.099994029725293,
#     'median_nan_count': 0,
#     'median_mean': 354985.19706396764,
#     'median_min': -22.0,
#     'median_max': 3904151.0,
#     'median_median': 0.16368435196960088,
#     'median_skew': 3.3166245920958257,
#     'median_perc_unique': 0.6363636363636364,
#     'median_perc_of_values_mode': 0.36363636363636365,
#     'median_mode': 0.0,
#     'median_kurtosis': 6.099999426059663,
#     'skew_nan_count': 0,
#     'skew_mean': -1.393071409219905,
#     'skew_min': -30.56141357987226,
#     'skew_max': 9.618400150065188,
#     'skew_median': -0.0013892422432399102,
#     'skew_skew': -2.641161334040383,
#     'skew_perc_unique': 0.9090909090909091,
#     'skew_perc_of_values_mode': 0.09090909090909091,
#     'skew_mode': 1.4251786122639991,
#     'skew_kurtosis': 4.452903130471333,
#     'perc_unique_nan_count': 0,
#     'perc_unique_mean': 0.16030757251313996,
#     'perc_unique_min': 0.0010706638115631692,
#     'perc_unique_max': 0.6627408993576017,
#     'perc_unique_median': 0.10813704496788008,
#     'perc_unique_skew': 1.9198944431669491,
#     'perc_unique_perc_unique': 0.9090909090909091,
#     'perc_unique_perc_of_values_mode': 0.09090909090909091,
#     'perc_unique_mode': 0.0053533190578158455,
#     'perc_unique_kurtosis': 2.0659169603577414,
#     'perc_of_values_mode_nan_count': 0,
#     'perc_of_values_mode_mean': 0.39634027642592956,
#     'perc_of_values_mode_min': 0.021413276231263382,
#     'perc_of_values_mode_max': 0.9989293361884368,
#     'perc_of_values_mode_median': 0.18522483940042828,
#     'perc_of_values_mode_skew': 0.7521323320810445,
#     'perc_of_values_mode_perc_unique': 0.9090909090909091,
#     'perc_of_values_mode_perc_of_values_mode': 0.09090909090909091,
#     'perc_of_values_mode_mode': 0.18522483940042828,
#     'perc_of_values_mode_kurtosis': -1.2763313088657098,
#     'mode_nan_count': 0,
#     'mode_mean': 365457.2096054828,
#     'mode_min': -1.5667941372620928,
#     'mode_max': 4020025.0,
#     'mode_median': 0.0,
#     'mode_skew': 3.3166247903444885,
#     'mode_perc_unique': 0.36363636363636365,
#     'mode_perc_of_values_mode': 0.6363636363636364,
#     'mode_mode': 0.0,
#     'mode_kurtosis': 6.099999999968421,
#     'kurtosis_nan_count': 0,
#     'kurtosis_mean': 97.3680270254023,
#     'kurtosis_min': -1.2024963878631127,
#     'kurtosis_max': 929.0010718113616,
#     'kurtosis_median': 1.23848983203479,
#     'kurtosis_skew': 3.24478893286961,
#     'kurtosis_perc_unique': 0.9090909090909091,
#     'kurtosis_perc_of_values_mode': 0.09090909090909091,
#     'kurtosis_mode': 27.249750860827504,
#     'kurtosis_kurtosis': 5.877742878280936,
#     'target_slope_nan_count': 0,
#     'target_slope_mean': 23620.14496255754,
#     'target_slope_min': -27881.06669950838,
#     'target_slope_max': 153083.14024585974,
#     'target_slope_median': 0.3841547530150552,
#     'target_slope_skew': 1.7532891535428314,
#     'target_slope_perc_unique': 0.9090909090909091,
#     'target_slope_perc_of_values_mode': 0.09090909090909091,
#     'target_slope_mode': -6986.009308896157,
#     'target_slope_kurtosis': 0.513548884963027,
#     'target_intercept_nan_count': 0,
#     'target_intercept_mean': 26802.055472026546,
#     'target_intercept_min': -1313219.597906344,
#     'target_intercept_max': 199473.18994696054,
#     'target_intercept_median': 169355.06087554336,
#     'target_intercept_skew': -3.2857924703842754,
#     'target_intercept_perc_unique': 0.9090909090909091,
#     'target_intercept_perc_of_values_mode': 0.09090909090909091,
#     'target_intercept_mode': 183122.58733481044,
#     'target_intercept_kurtosis': 6.009581351858342,
#     'target_r_value_nan_count': 0,
#     'target_r_value_mean': 0.16875207366633202,
#     'target_r_value_min': -0.2753004245884718,
#     'target_r_value_max': 0.5602129541171428,
#     'target_r_value_median': 0.2152915726237245,
#     'target_r_value_skew': -0.09162720046086462,
#     'target_r_value_perc_unique': 0.9090909090909091,
#     'target_r_value_perc_of_values_mode': 0.09090909090909091,
#     'target_r_value_mode': 0.552071994660601,
#     'target_r_value_kurtosis': -1.530292835406232,
#     'target_p_value_nan_count': 0,
#     'target_p_value_mean': 0.05188170922017155,
#     'target_p_value_min': 2.769575779706954e-78,
#     'target_p_value_max': 0.5044804290202147,
#     'target_p_value_median': 1.0492295844310504e-17,
#     'target_p_value_skew': 3.2225947936317927,
#     'target_p_value_perc_unique': 0.9090909090909091,
#     'target_p_value_perc_of_values_mode': 0.09090909090909091,
#     'target_p_value_mode': 2.769575779706954e-78,
#     'target_p_value_kurtosis': 5.803304171863287,
#     'target_std_err_nan_count': 0,
#     'target_std_err_mean': 3708.6732196374596,
#     'target_std_err_min': 1.287331145005518e-11,
#     'target_std_err_max': 15109.201254850372,
#     'target_std_err_median': 799.0971434832909,
#     'target_std_err_skew': 1.3295745964813925,
#     'target_std_err_perc_unique': 0.9090909090909091,
#     'target_std_err_perc_of_values_mode': 0.09090909090909091,
#     'target_std_err_mode': 7398.617499497093,
#     'target_std_err_kurtosis': 0.25777189481764573},
#    'dataset_id': '99da8e1a0ddd4127b36518f7495be093',
#    'datapath': '/home/td/Documents/datasets/housing_prices/train.csv',
#    'transformation_type': 'identity',
#    'transformation_parameters': {}}]]
